# %% [markdown]
# <a href="https://colab.research.google.com/github/Satchi99/Satchi99-pemrograman-komputer-5018241100/blob/main/Week02/WO2_Engineering_Calculator_5018241100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Student Information

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# Nama :Arrya Niam Syidada
# NRP :5018241100
# Kelas :A

# %% [markdown]
# # Task 1: Speed Unit Conversion

# %%
speed_kmh = float(input("Enter speed [km/h]: "))
speed_ms = speed_kmh / 3.6
print(f"Speed = {speed_ms:.2f} m/s")
# Out:
# Enter speed [km/h]: 100
# Speed = 27.78 m/s

# %% [markdown]
# # Task 2: Power Unit Conversion

# %%
# Masukkan nilai daya dalam kW
power_kw = float(input("Enter power [kW]: "))

# Konversi kW ke W (dikali 1000)
power_w = power_kw * 1000

# Tampilkan hasil dengan satuan W (Watt)
print(f"Power = {power_w:.2f} W")
# Out:
# Enter power [kW]: 100
# Power = 100000.00 W

# %% [markdown]
# # Task 3: Electrical Power and Energy Calculator

# %%
var_v = float(input("Enter Voltage [V]"))

var_a = float(input("Enter Amphere [A]"))

var_h = float(input("Enter Times (H)"))
var_p = var_v*var_a

print(f"===== ELECTRICAL CALCULATION =====")
print(f"Voltage = {var_v} V")
print(f"Current = {var_a} A")
print(f"Power = {var_p} W")
print(f"Operating Time = {var_h} hour")
print(f"Energy = {var_p*var_h} Wh")
# Out:
# Enter Voltage [V]100
# Enter Amphere [A]100
# Enter Times (H)100
# ===== ELECTRICAL CALCULATION =====
# Voltage = 100.0 V
# Current = 100.0 A
# Power = 10000.0 W
# Operating Time = 100.0 hour
# Energy = 1000000.0 Wh

# %% [markdown]
# # Task 4: Comparison and Logical Operators

# %%
power = var_p
voltage = var_v

power_limit = 200
voltage_limit = 24

is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
# Out:
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True

# %% [markdown]
# # Test Cases

# %%
var_v = 12

var_a = 5.0

var_h = 2.0

var_p = var_v*var_a
is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"===== ELECTRICAL CALCULATION =====")
print(f"Voltage = {var_v} V")
print(f"Current = {var_a} A")
print(f"Power = {var_p} W")
print(f"Operating Time = {var_h} hour")
print(f"Energy = {var_p*var_h} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
print(f"==================================")
# Out:
# ===== ELECTRICAL CALCULATION =====
# Voltage = 12 V
# Current = 5.0 A
# Power = 60.0 W
# Operating Time = 2.0 hour
# Energy = 120.0 Wh
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True
# ...

# %%
var_v = 24

var_a = 8.5

var_h = 3.0

var_p = var_v*var_a
is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"===== ELECTRICAL CALCULATION =====")
print(f"Voltage = {var_v} V")
print(f"Current = {var_a} A")
print(f"Power = {var_p} W")
print(f"Operating Time = {var_h} hour")
print(f"Energy = {var_p*var_h} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
print(f"==================================")
# Out:
# ===== ELECTRICAL CALCULATION =====
# Voltage = 24 V
# Current = 8.5 A
# Power = 204.0 W
# Operating Time = 3.0 hour
# Energy = 612.0 Wh
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True
# ...

# %%
var_v = 48

var_a = 10.0

var_h = 1.5

var_p = var_v*var_a
is_high_power = power > power_limit
is_high_voltage = voltage > voltage_limit

print(f"===== ELECTRICAL CALCULATION =====")
print(f"Voltage = {var_v} V")
print(f"Current = {var_a} A")
print(f"Power = {var_p} W")
print(f"Operating Time = {var_h} hour")
print(f"Energy = {var_p*var_h} Wh")
print(f"High power : {is_high_power}")
print(f"High voltage : {is_high_voltage}")
print(f"Both conditions : {is_high_power and is_high_voltage}")
print(f"Any condition : {is_high_power or is_high_voltage}")
print(f"==================================")
# Out:
# ===== ELECTRICAL CALCULATION =====
# Voltage = 48 V
# Current = 10.0 A
# Power = 480.0 W
# Operating Time = 1.5 hour
# Energy = 720.0 Wh
# High power : True
# High voltage : True
# Both conditions : True
# Any condition : True
# ...

# %% [markdown]
# # Short Reflection

# %% [markdown]
# Pada bagian akhir notebook, tambahkan Markdown Cell dan jawab secara singkat:
#
# ## Jawaban
#
# 1. **int** adalah bilangan bulat, sedangkan **float** adalah bilangan desimal.
#
# 2. Karena `input()` menghasilkan data berupa string, sehingga perlu dikonversi dengan `float()` agar dapat digunakan dalam perhitungan numerik.
#
# 3. `=` digunakan untuk memberikan nilai ke variabel, sedangkan `==` digunakan untuk membandingkan dua nilai.
#
# 4. `and` digunakan jika kedua kondisi harus benar, sedangkan `or` digunakan jika salah satu kondisi benar.
#
# 5. Saya lupa menggunakan `float()` pada `input()`, sehingga perhitungan tidak berjalan dengan benar. saya memperbaikinya dengan menambahkan `float()`.
